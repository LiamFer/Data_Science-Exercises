# %%
import pandas as pd

# %%
pd.set_option()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Windows\Desktop\Stuff\Coding\Data-Visualization\Pandas\K1.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Windows/Desktop/Stuff/Coding/Data-Visualization/Pandas/K1.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> pd.set_option()
#
# File c:\Users\Windows\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_config\config.py:272, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     271 def __call__(self, *args, **kwds) -> T:
# --> 272     return self.__func__(*args, **kwds)
#
# File c:\Users\Windows\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_config\config.py:157, in _set_option(*args, **kwargs)
#     155 nargs = len(args)
#     156 if not nargs or nargs % 2 != 0:
# --> 157     raise ValueError("Must provide an even number of non-keyword arguments")
#     159 # default to false
#     160 silent = kwargs.pop("silent", False)
#
# ValueError: Must provide an even number of non-keyword arguments

# %%
df = pd.read_table(r"http://bit.ly/chiporders")

df["choice_description"] = df["choice_description"].str.replace("]","")
df["choice_description"] = df["choice_description"].str.replace("[","")

a = df["choice_description"].str.split(",",expand=True)
choices = []
for col in range(len(a.columns)):
    choices.append(f"{col} Choice")
df[choices] = df["choice_description"].str.split(",",expand=True)
df
# Out:
#       order_id  quantity        item_name  \
# 1320       538         1  Chicken Burrito
# 2040       820         1  Chicken Burrito
# 2159       871         1  Chicken Burrito
# 3659      1463         1      Veggie Bowl
#
#                                      choice_description item_price  \
# 1320  Tomatillo-Green Chili Salsa (Medium), Roasted ...    $10.98
# 2040  Fresh Tomato Salsa (Mild), Tomatillo-Green Chi...     $8.49
# 2159  Tomatillo-Green Chili Salsa (Medium), Roasted ...    $10.98
# 3659  Fresh Tomato Salsa (Mild), Tomatillo-Green Chi...     $8.49
#
#                                   0 Choice  \
# 1320  Tomatillo-Green Chili Salsa (Medium)
# 2040             Fresh Tomato Salsa (Mild)
# 2159  Tomatillo-Green Chili Salsa (Medium)
# 3659             Fresh Tomato Salsa (Mild)
#
#                                    1 Choice  \
# 1320      Roasted Chili Corn Salsa (Medium)
# 2040   Tomatillo-Green Chili Salsa (Medium)
# 2159      Roasted Chili Corn Salsa (Medium)
# 3659   Tomatillo-Green Chili Salsa (Medium)
#
#                                 2 Choice                          3 Choice  \
# 1320     Tomatillo-Red Chili Salsa (Hot)                       Pinto Beans
# 2040     Tomatillo-Red Chili Salsa (Hot)                       Pinto Beans
# 2159                         Pinto Beans                       Black Beans
# 3659   Roasted Chili Corn Salsa (Medium)   Tomatillo-Red Chili Salsa (Hot)
#
#           4 Choice         5 Choice         6 Choice     7 Choice  \
# 1320          Rice   Fajita Veggies           Cheese   Sour Cream
# 2040   Black Beans             Rice   Fajita Veggies       Cheese
# 2159          Rice   Fajita Veggies           Cheese   Sour Cream
# 3659   Pinto Beans             Rice   Fajita Veggies       Cheese
#
#          8 Choice  9 Choice
# 1320    Guacamole   Lettuce
# 2040   Sour Cream   Lettuce
# 2159    Guacamole   Lettuce
# 3659   Sour Cream   Lettuce

# %%
df = pd.read_table(r"http://bit.ly/movieusers",sep="|",header=None)
df
# Out:
#        0   1  2              3      4
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# ..   ...  .. ..            ...    ...
# 938  939  26  F        student  33319
# 939  940  32  M  administrator  02215
# 940  941  20  M        student  97229
# 941  942  48  F      librarian  78209
# 942  943  22  M        student  77841
#
# [943 rows x 5 columns]

# %%
df = pd.read_csv(r"http://bit.ly/uforeports")
a = pd.DataFrame(df['City'].unique())

df["Localization"] = df['City'] + " | " + df['State']
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time               Localization
# 0        6/1/1930 22:00                Ithaca | NY
# 1       6/30/1930 20:00           Willingboro | NJ
# 2       2/15/1931 14:00               Holyoke | CO
# 3        6/1/1931 13:00               Abilene | KS
# 4       4/18/1933 19:00  New York Worlds Fair | NY
# ...                 ...                        ...
# 18236  12/31/2000 23:00            Grant Park | IL
# 18237  12/31/2000 23:00           Spirit Lake | IA
# 18238  12/31/2000 23:45           Eagle River | WI
# 18239  12/31/2000 23:45           Eagle River | WI
# 18240  12/31/2000 23:59                  Ybor | FL
#
# [18241 rows x 6 columns]
