# %%
import pandas as pd

# %%
df = pd.read_table(r"http://bit.ly/chiporders")

df["choice_description"] = df["choice_description"].str.replace("]","")
df["choice_description"] = df["choice_description"].str.replace("[","")

a = df["choice_description"].str.split(",",expand=True)
choices = []
for col in range(len(a.columns)):
    choices.append(f"{col} Choice")
df[choices] = df["choice_description"].str.split(",",expand=True)
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                                   NaN     $2.39
# ...

# %%
df = pd.read_table(r"http://bit.ly/movieusers",sep="|",header=None)
df
# Out:
#        0   1  2              3      4
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# ..   ...  .. ..            ...    ...
# 938  939  26  F        student  33319
# 939  940  32  M  administrator  02215
# 940  941  20  M        student  97229
# 941  942  48  F      librarian  78209
# 942  943  22  M        student  77841
#
# [943 rows x 5 columns]

# %%
df = pd.read_csv(r"http://bit.ly/uforeports")
a = pd.DataFrame(df['City'].unique())

df["Localization"] = df['City'] + " | " + df['State']
df.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time',
#        'Localization'],
#       dtype='object')

# %%
df = pd.read_csv(r"http://bit.ly/imdbratings")

date_series = pd.DataFrame(pd.date_range(start = '05-01-2021', end = '05-12-2021'))
date_series
# Out:
#             0
# 0  2021-05-01
# 1  2021-05-02
# 2  2021-05-03
# 3  2021-05-04
# 4  2021-05-05
# 5  2021-05-06
# 6  2021-05-07
# 7  2021-05-08
# 8  2021-05-09
# 9  2021-05-10
# 10 2021-05-11
# 11 2021-05-12
